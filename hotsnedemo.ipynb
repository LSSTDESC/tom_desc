# %%
import sys
import os
import pandas

from tom_client import TomClient

from IPython.display import display, HTML

# %%
tom = TomClient( url='https://desc-tom-2.lbl.gov', username='rknop',
                 passwordfile='/global/homes/r/raknop/secrets/tom_rknop_passwd' )

# %%
res = tom.request( 'POST', 'elasticc2/gethotsne/10/' )

# %%
res.json()
# Out:
# {'1028916': {'photometry': {'mjd': [60796.0521,
#     60796.0759,
#     60796.1809,
#     60796.2033],
#    'band': ['g', 'u', 'u', 'g'],
#    'flux': [4137.211, 172.19733, 156.72322, 933.2661],
#    'fluxerr': [139.66222, 313.02737, 273.88834, 147.8702]},
#   'zp': 27.5,
#   'redshift': -99,
#   'sncode': -99},
#  '1032366': {'photometry': {'mjd': [60796.1393],
#    'band': ['g'],
#    'flux': [877.2865],
#    'fluxerr': [154.4474]},
#   'zp': 27.5,
#   'redshift': -99,
#   'sncode': -99},
#  '1033692': {'photometry': {'mjd': [60796.2868, 60796.3089],
#    'band': ['u', 'g'],
#    'flux': [3844.5356, 1691.9396],
#    'fluxerr': [795.04083, 263.3025]},
#   'zp': 27.5,
#   'redshift': -99,
#   'sncode': -99},
#  '1033933': {'photometry': {'mjd': [60796.098,
#     60796.1212,
#     60796.1925,
#     60796.2158],
#    'band': ['u', 'g', 'u', 'g'],
#    'flux': [56918.61, 100103.055, 58900.504, 100435.14],
#    'fluxerr': [874.8251, 761.9509, 1271.9744, 876.8327]},
#   'zp': 27.5,
# ...
